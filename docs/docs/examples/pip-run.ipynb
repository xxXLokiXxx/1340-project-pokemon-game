# %%
import os
os.environ['OPENAI_API_KEY'] = 'your_openai_api_key'
os.environ['TAVILY_API_KEY'] = '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' # Get a free key here: https://app.tavily.com

# %%
# !pip install -U gpt-researcher nest_asyncio
# Out:
# Collecting gpt-researcher
#   Downloading gpt_researcher-0.14.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (24.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.6.1)
# Collecting aiohttp>=3.12.0 (from gpt-researcher)
#   Downloading aiohttp-3.12.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: aiosignal>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.4.0)
# Requirement already satisfied: annotated-types>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.7.0)
# Requirement already satisfied: anyio>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (4.9.0)
# Collecting arxiv>=2.0.0 (from gpt-researcher)
#   Downloading arxiv-2.2.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: attrs>=25.3.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (25.3.0)
# Collecting backoff>=2.2.1 (from gpt-researcher)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: beautifulsoup4>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (4.13.4)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.1.0)
# Requirement already satisfied: certifi>=2025.4.26 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2025.7.14)
# Requirement already satisfied: cffi>=1.17.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.17.1)
# Requirement already satisfied: chardet>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (5.2.0)
# Requirement already satisfied: charset-normalizer>=3.4.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.4.2)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (8.2.1)
# Collecting colorama>=0.4.6 (from gpt-researcher)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting cryptography>=45.0.2 (from gpt-researcher)
#   Downloading cryptography-45.0.5-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting cssselect2>=0.8.0 (from gpt-researcher)
#   Downloading cssselect2-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dataclasses-json>=0.6.7 (from gpt-researcher)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: distro>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.9.0)
# Collecting docopt>=0.6.2 (from gpt-researcher)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting duckduckgo-search>=4.1.1 (from gpt-researcher)
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting emoji>=2.14.1 (from gpt-researcher)
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: fastapi>=0.104.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.116.1)
# Collecting feedparser>=6.0.11 (from gpt-researcher)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: filelock>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.18.0)
# Collecting filetype>=1.2.0 (from gpt-researcher)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fonttools>=4.58.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (4.59.0)
# Requirement already satisfied: frozenlist>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.7.0)
# Requirement already satisfied: fsspec>=2025.5.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2025.7.0)
# Requirement already satisfied: greenlet>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.2.3)
# Requirement already satisfied: h11>=0.16.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.16.0)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.1)
# Collecting htmldocx>=0.0.6 (from gpt-researcher)
#   Downloading htmldocx-0.0.6-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.28.1)
# Collecting httpx-aiohttp>=0.1.4 (from gpt-researcher)
#   Downloading httpx_aiohttp-0.1.8-py3-none-any.whl.metadata (2.8 kB)
# Collecting httpx-sse>=0.4.0 (from gpt-researcher)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: huggingface-hub>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.33.4)
# Requirement already satisfied: idna>=3.10 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.10)
# Requirement already satisfied: importlib-metadata>=8.7.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (8.7.0)
# Requirement already satisfied: jinja2>=3.1.6 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.1.6)
# Requirement already satisfied: jiter>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.10.0)
# Requirement already satisfied: joblib>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.5.1)
# Collecting json-repair>=0.44.0 (from gpt-researcher)
#   Downloading json_repair-0.47.8-py3-none-any.whl.metadata (12 kB)
# Collecting json5>=0.12.0 (from gpt-researcher)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonpatch>=1.33 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.33)
# Requirement already satisfied: jsonpointer>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.0.0)
# Requirement already satisfied: jsonschema>=4.23.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (4.25.0)
# Requirement already satisfied: jsonschema-specifications>=2025.4.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2025.4.1)
# Requirement already satisfied: kiwisolver>=1.4.8 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.4.8)
# Collecting langchain-community>=0.3.17 (from gpt-researcher)
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core>=0.3.61 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.3.70)
# Collecting langchain-ollama>=0.3.3 (from gpt-researcher)
#   Downloading langchain_ollama-0.3.6-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-openai>=0.3.6 (from gpt-researcher)
#   Downloading langchain_openai-0.3.28-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain-text-splitters>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.3.8)
# Collecting langdetect>=1.0.9 (from gpt-researcher)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting langgraph>=0.2.76 (from gpt-researcher)
#   Downloading langgraph-0.5.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting langgraph-checkpoint>=2.0.26 (from gpt-researcher)
#   Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting langgraph-cli>=0.2.10 (from gpt-researcher)
#   Downloading langgraph_cli-0.3.6-py3-none-any.whl.metadata (3.8 kB)
# Collecting langgraph-sdk>=0.1.70 (from gpt-researcher)
#   Downloading langgraph_sdk-0.2.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langsmith>=0.3.42 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.4.8)
# Collecting litellm>=1.71.0 (from gpt-researcher)
#   Downloading litellm-1.74.8-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.0 MB/s eta 0:00:00
# Collecting loguru>=0.7.3 (from gpt-researcher)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: lxml>=5.4.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (5.4.0)
# Requirement already satisfied: markdown>=3.8 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.8.2)
# Collecting markdown2>=2.5.3 (from gpt-researcher)
#   Downloading markdown2-2.5.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: markupsafe>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.0.2)
# Collecting marshmallow>=3.26.1 (from gpt-researcher)
#   Downloading marshmallow-4.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting mcp>=1.9.1 (from gpt-researcher)
#   Downloading mcp-1.12.1-py3-none-any.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.4 MB/s eta 0:00:00
# Collecting md2pdf>=1.0.1 (from gpt-researcher)
#   Downloading md2pdf-1.0.1.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mistune>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.1.3)
# Requirement already satisfied: multidict>=6.4.4 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (6.6.3)
# Collecting mypy-extensions>=1.1.0 (from gpt-researcher)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: nltk>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.9.1)
# Collecting numpy>=2.2.6 (from gpt-researcher)
#   Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.9 MB/s eta 0:00:00
# Collecting olefile>=0.47 (from gpt-researcher)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting ollama>=0.4.8 (from gpt-researcher)
#   Downloading ollama-0.5.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: openai>=1.82.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.97.0)
# Requirement already satisfied: orjson>=3.10.18 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.11.0)
# Collecting ormsgpack>=1.10.0 (from gpt-researcher)
#   Downloading ormsgpack-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (25.0)
# Requirement already satisfied: pillow>=11.2.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (11.3.0)
# Collecting primp>=0.15.0 (from gpt-researcher)
#   Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: propcache>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.3.2)
# Collecting psutil>=7.0.0 (from gpt-researcher)
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pycparser>=2.22 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.22)
# Requirement already satisfied: pydantic>=2.11.5 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.11.7)
# Requirement already satisfied: pydantic-core>=2.33.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.33.2)
# Collecting pydantic-settings>=2.9.1 (from gpt-researcher)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydyf>=0.11.0 (from gpt-researcher)
#   Downloading pydyf-0.11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pymupdf>=1.26.0 (from gpt-researcher)
#   Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting pypdf>=5.5.0 (from gpt-researcher)
#   Downloading pypdf-5.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting pyphen>=0.17.2 (from gpt-researcher)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting python-docx>=1.1.2 (from gpt-researcher)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-dotenv>=1.1.0 (from gpt-researcher)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting python-iso639>=2025.2.18 (from gpt-researcher)
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting python-magic>=0.4.27 (from gpt-researcher)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-multipart>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.0.20)
# Collecting python-oxmsg>=0.0.2 (from gpt-researcher)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pyyaml>=6.0.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (6.0.2)
# Collecting rapidfuzz>=3.13.0 (from gpt-researcher)
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: referencing>=0.36.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.36.2)
# Requirement already satisfied: regex>=2024.11.6 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2024.11.6)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.0.0)
# Requirement already satisfied: rpds-py>=0.25.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.26.0)
# Collecting sgmllib3k>=1.0.0 (from gpt-researcher)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.17.0)
# Requirement already satisfied: sniffio>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.3.1)
# Requirement already satisfied: soupsieve>=2.7 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.7)
# Requirement already satisfied: sqlalchemy>=2.0.41 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.0.41)
# Collecting sse-starlette>=2.3.5 (from gpt-researcher)
#   Downloading sse_starlette-2.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: starlette>=0.46.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.47.2)
# Collecting tenacity>=9.1.2 (from gpt-researcher)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: tiktoken>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.9.0)
# Requirement already satisfied: tinycss2>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.4.0)
# Collecting tinyhtml5>=2.0.0 (from gpt-researcher)
#   Downloading tinyhtml5-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.21.2)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.13.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (4.14.1)
# Collecting typing-inspect>=0.9.0 (from gpt-researcher)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.4.1)
# Collecting unstructured>=0.17.2 (from gpt-researcher)
#   Downloading unstructured-0.18.11-py3-none-any.whl.metadata (24 kB)
# Collecting unstructured-client>=0.35.0 (from gpt-researcher)
#   Downloading unstructured_client-0.40.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: urllib3>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (2.5.0)
# Requirement already satisfied: uvicorn>=0.34.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.35.0)
# Collecting weasyprint>=65.1 (from gpt-researcher)
#   Downloading weasyprint-65.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: webencodings>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.5.1)
# Requirement already satisfied: websockets>=15.0.1 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (15.0.1)
# Collecting win32-setctime>=1.2.0 (from gpt-researcher)
#   Downloading win32_setctime-1.2.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wrapt>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.17.2)
# Requirement already satisfied: yarl>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (1.20.1)
# Requirement already satisfied: zipp>=3.21.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (3.23.0)
# Collecting zopfli>=0.2.3.post1 (from gpt-researcher)
#   Downloading zopfli-0.2.3.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from gpt-researcher) (0.23.0)
# Collecting marshmallow>=3.26.1 (from gpt-researcher)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.32.0->gpt-researcher) (1.1.5)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain-community>=0.3.17->gpt-researcher) (0.3.26)
# Collecting langgraph-prebuilt<0.6.0,>=0.5.0 (from langgraph>=0.2.76->gpt-researcher)
#   Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting langgraph-sdk>=0.1.70 (from gpt-researcher)
#   Downloading langgraph_sdk-0.1.74-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from langgraph>=0.2.76->gpt-researcher) (3.5.0)
# Downloading gpt_researcher-0.14.2-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.0/195.0 kB 14.3 MB/s eta 0:00:00
# Downloading aiohttp-3.12.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.7 MB/s eta 0:00:00
# Downloading arxiv-2.2.0-py3-none-any.whl (11 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading cryptography-45.0.5-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 47.9 MB/s eta 0:00:00
# Downloading cssselect2-0.8.0-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 36.8 MB/s eta 0:00:00
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.9 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading htmldocx-0.0.6-py3-none-any.whl (9.5 kB)
# Downloading httpx_aiohttp-0.1.8-py3-none-any.whl (6.2 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading json_repair-0.47.8-py3-none-any.whl (26 kB)
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 78.2 MB/s eta 0:00:00
# Downloading langchain_ollama-0.3.6-py3-none-any.whl (24 kB)
# Downloading langchain_openai-0.3.28-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 5.5 MB/s eta 0:00:00
# Downloading langgraph-0.5.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 11.7 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.1.1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 3.2 MB/s eta 0:00:00
# Downloading langgraph_cli-0.3.6-py3-none-any.whl (36 kB)
# Downloading langgraph_sdk-0.1.74-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 3.9 MB/s eta 0:00:00
# Downloading litellm-1.74.8-py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 54.6 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.0 MB/s eta 0:00:00
# Downloading markdown2-2.5.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00
# Downloading mcp-1.12.1-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.5/158.5 kB 13.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 43.5 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 10.4 MB/s eta 0:00:00
# Downloading ollama-0.5.1-py3-none-any.whl (13 kB)
# Downloading ormsgpack-1.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 15.5 MB/s eta 0:00:00
# Downloading primp-0.15.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 79.8 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 17.6 MB/s eta 0:00:00
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.7 MB/s eta 0:00:00
# Downloading pydyf-0.11.0-py3-none-any.whl (8.1 kB)
# Downloading pymupdf-1.26.3-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 41.0 MB/s eta 0:00:00
# Downloading pypdf-5.8.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 21.2 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.4 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 18.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 13.5 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 77.9 MB/s eta 0:00:00
# Downloading sse_starlette-2.4.1-py3-none-any.whl (10 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading tinyhtml5-2.0.0-py3-none-any.whl (39 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading unstructured-0.18.11-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 73.8 MB/s eta 0:00:00
# Downloading unstructured_client-0.40.0-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 17.1 MB/s eta 0:00:00
# Downloading weasyprint-65.1-py3-none-any.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 22.9 MB/s eta 0:00:00
# Downloading win32_setctime-1.2.0-py3-none-any.whl (4.1 kB)
# Downloading zopfli-0.2.3.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (850 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 850.6/850.6 kB 40.0 MB/s eta 0:00:00
# Downloading langgraph_prebuilt-0.5.2-py3-none-any.whl (23 kB)
# Building wheels for collected packages: docopt, langdetect, md2pdf, sgmllib3k
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=95d3938ca4240aaa960f9ab473c68156ac30beec441a20bb2ab4da2340b7988c
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=3ecbddcdce850beb20a97a44334f5facea9e5b5f1de592eb235e72ec1f67a263
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for md2pdf (setup.py) ... done
#   Created wheel for md2pdf: filename=md2pdf-1.0.1-py2.py3-none-any.whl size=6001 sha256=ac4fa77b2bcdf08c595104c87fa9e9a276f732460d6511a92cbfd3c0bb33c11c
#   Stored in directory: /root/.cache/pip/wheels/ab/c3/29/09f3661b6b4eceb291241be520bb55b12b2a6714af18ae1510
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=b9da35be7622cd920395fa80d1487bc0e5e695be6112246da8a002eb2f13370d
#   Stored in directory: /root/.cache/pip/wheels/3b/25/2a/105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built docopt langdetect md2pdf sgmllib3k
# Installing collected packages: sgmllib3k, filetype, docopt, zopfli, win32-setctime, tinyhtml5, tenacity, rapidfuzz, python-magic, python-iso639, python-dotenv, python-docx, pyphen, pypdf, pymupdf, pydyf, psutil, primp, ormsgpack, olefile, numpy, mypy-extensions, marshmallow, markdown2, loguru, langdetect, json5, json-repair, httpx-sse, feedparser, emoji, colorama, backoff, typing-inspect, sse-starlette, python-oxmsg, htmldocx, duckduckgo-search, cssselect2, cryptography, arxiv, aiohttp, weasyprint, unstructured-client, pydantic-settings, ollama, langgraph-sdk, httpx-aiohttp, dataclasses-json, unstructured, md2pdf, mcp, litellm, langgraph-cli, langgraph-checkpoint, langchain-openai, langchain-ollama, langgraph-prebuilt, langgraph, langchain-community, gpt-researcher
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.1 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# google-genai 1.26.0 requires tenacity<9.0.0,>=8.2.3, but you have tenacity 9.1.2 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 45.0.5 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 45.0.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.1 which is incompatible.
# Successfully installed aiohttp-3.12.14 arxiv-2.2.0 backoff-2.2.1 colorama-0.4.6 cryptography-45.0.5 cssselect2-0.8.0 dataclasses-json-0.6.7 docopt-0.6.2 duckduckgo-search-8.1.1 emoji-2.14.1 feedparser-6.0.11 filetype-1.2.0 gpt-researcher-0.14.2 htmldocx-0.0.6 httpx-aiohttp-0.1.8 httpx-sse-0.4.1 json-repair-0.47.8 json5-0.12.0 langchain-community-0.3.27 langchain-ollama-0.3.6 langchain-openai-0.3.28 langdetect-1.0.9 langgraph-0.5.4 langgraph-checkpoint-2.1.1 langgraph-cli-0.3.6 langgraph-prebuilt-0.5.2 langgraph-sdk-0.1.74 litellm-1.74.8 loguru-0.7.3 markdown2-2.5.3 marshmallow-3.26.1 mcp-1.12.1 md2pdf-1.0.1 mypy-extensions-1.1.0 numpy-2.3.1 olefile-0.47 ollama-0.5.1 ormsgpack-1.10.0 primp-0.15.0 psutil-7.0.0 pydantic-settings-2.10.1 pydyf-0.11.0 pymupdf-1.26.3 pypdf-5.8.0 pyphen-0.17.2 python-docx-1.2.0 python-dotenv-1.1.1 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.13.0 sgmllib3k-1.0.0 sse-starlette-2.4.1 tenacity-9.1.2 tinyhtml5-2.0.0 typing-inspect-0.9.0 unstructured-0.18.11 unstructured-client-0.40.0 weasyprint-65.1 win32-setctime-1.2.0 zopfli-0.2.3.post1

# %%
import nest_asyncio # required for notebooks
nest_asyncio.apply()

from gpt_researcher import GPTResearcher
import asyncio

async def get_report(query: str, report_type: str) -> str:
    researcher = GPTResearcher(query, report_type)
    research_result = await researcher.conduct_research()
    report = await researcher.write_report()

    # Get additional information
    research_context = researcher.get_research_context()
    research_costs = researcher.get_costs()
    research_images = researcher.get_research_images()
    research_sources = researcher.get_research_sources()

    return report, research_context, research_costs, research_images, research_sources

if __name__ == "__main__":
    query = "Should I invest in Nvidia?"
    report_type = "research_report"

    report, context, costs, images, sources = asyncio.run(get_report(query, report_type))

    print("Report:")
    print(report)
    print("\nResearch Costs:")
    print(costs)
    print("\nResearch Images:")
    print(images)
    print("\nResearch Sources:")
    print(sources)
